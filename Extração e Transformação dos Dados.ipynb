# %% [markdown]
# ## Extracao dos Dados

# %%
# Importando a biblioteca pandas
import pandas as pd

# %%
# Extraindo as informacoes da fonte de dados (arquivos .csv) e salvando em DataFrames
books = pd.read_csv('/Users/rafaelciriello/Data Engineer/Projects/personal_library_data_project/data/books.csv')
loans = pd.read_csv('/Users/rafaelciriello/Data Engineer/Projects/personal_library_data_project/data/loans.csv')
wishlist = pd.read_csv('/Users/rafaelciriello/Data Engineer/Projects/personal_library_data_project/data/wishlist.csv')

# %%
# Exibindo uma previa das informacoes extraidas
books.head(n = 2)
# Out:
#          titulo  paginas     ano   genero localizacao   lido classificacao  \
# 0  Dom Casmurro    280.0  1899.0  Romance           E  False             -
# 1           NaN      NaN     NaN      NaN         NaN    NaN           NaN
#
#               autor pais  nascimento
# 0  Machado de Assis   BR      1839.0
# 1               NaN  NaN         NaN

# %%
loans.head(n = 2)
# Out:
#      nome_pessoa data_emprestimo data_devolucao livro_emprestado
# 0     joão silva      2023-08-15     2023-09-01     Dom Casmurro
# 1  ana biachinni      2023-08-20            NaN             1984

# %%
wishlist.head(n = 2)
# Out:
#                         titulo nome_autor sobrenome_autor  lancamento  \
# 0         A Casa dos Espíritos     Isabel         Allende        1982
# 1  A Menina que Roubava Livros     Markus           Zusak        2005
#
#                                          comentarios     capa_livro
# 0              O realismo mágico desta obra me atrai            NaN
# 1   Segunda Guerra Mundial desperta minha curiosi...   convencional

# %% [markdown]
# ## Transformacao e Limpeza dos Dados

# %% [markdown]
# Agora que realizamos a extracao dos dados de nossos arquivos em formato csv vamos realizar a limpeza e o tratamendo destes dados utilizando os Data Frames gerados durante o processo de extracao.

# %% [markdown]
# ### Data Frame "books"

# %% [markdown]
# - Vamos analisar o Data Frame e identificar quais dados devemos tratar
# - Podemos notar que ele contem dados para alimentar duas tabelas do nosso Banco de Dados ("book" e "author")
# - Notamos os seguintes problemas na nossa base de dados:
#     1. Existem linhas de registros completamente vazias (ex: linha 1)
#     2. Existem registros duplicados (ex: 1984, linha 2 e linha 19)
#     3. A coluna genero tem dos valore para a mesma classificacao (ex: linha 2'Ficção Científica' e linha 20 "Ficção")
#     4. A coluna coluna classificacao possui "-" quando nao ha uma avaliacao do livro (ex: linha 0)
#     5. A coluna pais apresenta a sigla "BR" em alguns registros (ex: linha 0)

# %%
books
# Out:
#                                      titulo  paginas     ano  \
# 0                              Dom Casmurro    280.0  1899.0
# 1                                       NaN      NaN     NaN
# 2                                      1984    328.0  1949.0
# 3                    A Revolução dos Bichos    144.0  1945.0
# 4                           O Grande Gatsby    180.0  1925.0
# 5                                  O Hobbit    310.0  1937.0
# 6                                       NaN      NaN     NaN
# 7           O Apanhador no Campo de Centeio    224.0  1951.0
# 8                           Crime e Castigo    671.0  1866.0
# 9                             Anna Karenina    864.0  1877.0
# 10                       O Pequeno Príncipe     93.0  1943.0
# 11     O Leão a Feiticeira e o Guarda-Roupa    206.0  1950.0
# 12                               O Processo    266.0  1925.0
# 13                                      NaN      NaN     NaN
# 14                       A Revolta de Atlas   1088.0  1957.0
# 15                  O Conde de Monte Cristo   1310.0  1844.0
# 16                        A Montanha Mágica    912.0  1924.0
# 17                 O Retrato de Dorian Gray    254.0  1890.0
# 18                   Grande Sertão: Veredas    616.0  1956.0
# 19                                     1984    328.0  1949.0
# 20                                A Estrada    239.0  2006.0
# 21                 Um Conto de Duas Cidades    432.0  1859.0
# 22                           O Nome da Rosa    504.0  1980.0
# 23                          Romeu e Julieta    336.0  1597.0
# 24                           Fahrenheit 451    208.0  1953.0
# 25                           Fahrenheit 451    208.0  1953.0
# 26                      Cem Anos de Solidão    457.0  1967.0
# 27                                      NaN      NaN     NaN
# 28                       O Sol é para Todos    364.0  1960.0
# 29                        Matar um Rouxinol    286.0  1960.0
# 30                          O Grande Gatsby    180.0  1925.0
# 31                            A Metamorfose     55.0  1915.0
# 32  O Senhor dos Anéis: A Sociedade do Anel    423.0  1954.0
# 33                   A Culpa é das Estrelas    288.0  2012.0
# 34                        Matar um Rouxinol    286.0  1960.0
# 35                             Dom Casmurro    280.0  1899.0
# 36                        O Código Da Vinci    456.0  2003.0
#
#                genero localizacao   lido classificacao  \
# 0             Romance           E  False             -
# 1                 NaN         NaN    NaN           NaN
# 2   Ficção Científica           F   True             2
# 3   Ficção Científica           C   True             4
# 4             Romance           D  False             -
# 5            Fantasia           E   True             3
# 6                 NaN         NaN    NaN           NaN
# 7             Romance           A   True             4
# 8             Romance           F   True             2
# 9             Romance           B   True             4
# 10             Fábula           D   True             3
# 11           Fantasia           A   True             5
# 12            Romance           E   True             1
# 13                NaN         NaN    NaN           NaN
# 14  Ficção Científica           C  False             -
# 15           Aventura           E   True             2
# 16            Romance           B   True             5
# 17            Romance           F  False             -
# 18            Romance           E   True             1
# 19  Ficção Científica           F   True             2
# 20             Ficção           F   True             4
# 21            Romance           C   True             2
# 22           Mistério           B   True             3
# 23           Tragédia           F   True             2
# 24  Ficção Científica           E   True             4
# 25  Ficção Científica           E   True             4
# 26             Ficção           M   True             5
# 27                NaN         NaN    NaN           NaN
# 28             Ficção           D   True             3
# 29            Romance           E   True             4
# 30            Romance           A   True           NaN
# 31             Ficção           B   True             1
# 32           Fantasia           C   True             5
# 33            Romance           D   True             2
# 34            Romance           E   True             4
# 35            Romance           F   True           NaN
# 36           Mistério           G   True             1
#
#                        autor            pais  nascimento
# 0           Machado de Assis              BR      1839.0
# 1                        NaN             NaN         NaN
# 2              George Orwell     Reino Unido      1903.0
# 3              George Orwell     Reino Unido      1903.0
# 4        F. Scott Fitzgerald  Estados Unidos      1896.0
# 5             J.R.R. Tolkien     Reino Unido      1892.0
# 6                        NaN             NaN         NaN
# 7              J.D. Salinger  Estados Unidos      1919.0
# 8         Fiodor Dostoievski          Rússia      1821.0
# 9                Lev Tolstói          Rússia      1828.0
# 10  Antoine de Saint-Exupéry          França      1900.0
# 11                C.S. Lewis     Reino Unido      1898.0
# 12               Franz Kafka         Áustria      1883.0
# 13                       NaN             NaN         NaN
# 14                  Ayn Rand          Rússia      1905.0
# 15           Alexandre Dumas          França      1802.0
# 16               Thomas Mann        Alemanha      1875.0
# 17               Oscar Wilde     Reino Unido      1854.0
# 18       João Guimarães Rosa              BR      1908.0
# 19             George Orwell     Reino Unido      1903.0
# 20           Cormac McCarthy  Estados Unidos      1933.0
# 21           Charles Dickens     Reino Unido      1812.0
# 22               Umberto Eco          Itália      1932.0
# 23       William Shakespeare     Reino Unido      1564.0
# 24              Ray Bradbury  Estados Unidos      1920.0
# 25              Ray Bradbury  Estados Unidos      1920.0
# 26    Gabriel García Márquez        Colômbia      1927.0
# 27                       NaN             NaN         NaN
# 28                Harper Lee  Estados Unidos      1926.0
# 29                Harper Lee  Estados Unidos      1926.0
# 30       F. Scott Fitzgerald  Estados Unidos      1896.0
# 31               Franz Kafka         Áustria      1883.0
# 32            J.R.R. Tolkien     Reino Unido      1892.0
# 33                John Green  Estados Unidos      1977.0
# 34                Harper Lee  Estados Unidos      1926.0
# 35          Machado de Assis              BR      1839.0
# 36                 Dan Brown  Estados Unidos      1964.0

# %% [markdown]
# #### 1. Linhas Vazias

# %%
# verificando se existem linhas completamente vazias nos dados
# True indica a existencia de linhas(axis=1) vazias no DF
books.isnull().all(axis=1).any()
# Out:
# True

# %%
# Removendo linhas vazias do DataFrame
books = books.dropna(how = 'any')

# %%
# Verificando se a exclusao foi realizada
# False indica que nao ha presenca de linhas vazias no DF
books.isnull().all(axis=1).any()
# Out:
# False

# %% [markdown]
# #### 2. Registros Duplicados

# %%
# O comando abaixo retorna True caso haja regsistros duplicados e False em caso negativo
books.duplicated().any()
# Out:
# True

# %%
# Por se tratar de um conjunto de dados relativamente pequeno
# Podemos verificar a ocorrencia de duplicatas de forma visual, ordenando os livros por titulo por exemplo
books.sort_values(by='titulo').head(n = 2)
# Out:
#    titulo  paginas     ano             genero localizacao  lido classificacao  \
# 2    1984    328.0  1949.0  Ficção Científica           F  True             2
# 19   1984    328.0  1949.0  Ficção Científica           F  True             2
#
#             autor         pais  nascimento
# 2   George Orwell  Reino Unido      1903.0
# 19  George Orwell  Reino Unido      1903.0

# %%
# Neste nosso exemplo sabemos que a biblioteca possui apenas um exemplar de cada livro
# Desta forma, vamos realizar a exclusao dos registros duplicados no DF
books = books.drop_duplicates()

# %%
# Verificando se a exclusao foi realizada com sucesso
# False indica que nao existem registros duplicados
books.duplicated().any()
# Out:
# False

# %% [markdown]
# #### 3. Tratando dados na coluna "genero"

# %%
# Substituindo valores na coluna genero
# Quando o valor nesta coluna for igual a "Ficção Científica" sera substituido por "Ficção"
books['genero'] = books['genero'].replace({'Ficção Científica': 'Ficção'})

# %% [markdown]
# #### 4. Tratando dados na coluna "cassificacao"

# %%
# Substituindo valores na coluna classificacao
# Quando o valor desta coluna for igual a "-" sera substituiso por nulo (valor ausente)
books['classificacao'] = books['classificacao'].replace({'-': pd.NA})

# %% [markdown]
# #### 5. Tratando dados na coluna "pais"

# %%
# Substituindo valores na coluna pais
# Quando o valor nesta coluna for igual a sigla "BR" sera substituido por "Brasil"
books['pais'] = books['pais'].replace({'BR': 'Brasil'})

# %% [markdown]
# #### 6. Renomeando as colunas do Data Frame

# %%
# Renomeando as colunas do Data Frame com os mesmos nomes das colunas do Banco de Dados
books.columns = [['title', 'pages', 'year', 'genre', 'location', 'read', 'rating', 'author', 'country', 'birth']]

# %% [markdown]
# #### 7. Separando o Data Frame em dois Data Frames

# %%
# Vamos separar estas informacoes em dois DF diferentes
# Vamos organizar as colunas da mesma forma que aparecem no nosso Banco de Dados
author = books[['author', 'country', 'birth']]
book = books[['title', 'year', 'genre', 'pages', 'location', 'read', 'rating']]

# %% [markdown]
# #### 8. Salvando os dados em arquivos csv

# %%
# Salvando os dados tratados em arquivos csv para posterior carregamento no Banco de Dados
# Estou usando uma pasta chamada "clean data" para facilitar o entendimento e organizar os arquivos
# O "index = False" no comando abaixo evita que o indice gerado no DF seja salvo no arquivo
author.to_csv('/Users/rafaelciriello/Data Engineer/Projects/personal_library_data_project/clean data/author.csv', index = False)
book.to_csv('/Users/rafaelciriello/Data Engineer/Projects/personal_library_data_project/clean data/book.csv', index = False)

# %% [markdown]
# ### Data Frame "loans"

# %%
loans
# Out:
#         nome_pessoa data_emprestimo data_devolucao  \
# 0        joão silva      2023-08-15     2023-09-01
# 1     ana biachinni      2023-08-20            NaN
# 2     paulo strongs      2023-08-25     2023-09-15
# 3   carla fernandes      2023-08-18            NaN
# 4  andré nascimento      2023-08-22            NaN
# 5    maria madalena      2023-08-27     2023-09-17
# 6        joão silva      2023-08-30            NaN
#
#                           livro_emprestado
# 0                             Dom Casmurro
# 1                                     1984
# 2                   A Revolução dos Bichos
# 3                      Cem Anos de Solidão
# 4                          O Grande Gatsby
# 5                                 O Hobbit
# 6  O Senhor dos Anéis: A Sociedade do Anel

# %%
# renomear as colunas de acordo com o banco de dados
# tratar o nome das pessoas para que os nomes fiquem no formato (title)
# subistituir os valores vazios da coluna data de devolucao por null
# coluna livro emprestado deve ser substituida pelo id do resoectivo livro (fk)

# %% [markdown]
# #### DataFrame df_wishlist

# %%
df_wishlist
# Out:
#                         titulo    nome_autor sobrenome_autor  lancamento  \
# 0         A Casa dos Espíritos        Isabel         Allende        1982
# 1  A Menina que Roubava Livros        Markus           Zusak        2005
# 2                A Sangue Frio        Truman          Capote        1966
# 3            A Sombra do Vento   Carlos Ruiz           Zafón        2001
# 4        As Crônicas de Nárnia          C.S.           Lewis        1950
# 5                O Estrangeiro        Albert           Camus        1942
# 6             Laranja Mecânica       Anthony         Burgess        1962
# 7         Admirável Mundo Novo        Aldous          Huxley        1932
# 8                Os Miseráveis        Victor            Hugo        1862
# 9              O Som e a Fúria       William        Faulkner        1929
#
#                                          comentarios           capa_livro
# 0              O realismo mágico desta obra me atrai                  NaN
# 1   Segunda Guerra Mundial desperta minha curiosi...         convencional
# 2           Gosto de livros baseados em eventos reai         qualquer uma
# 3   A premissa de uma livraria misteriosa me inte...                 dura
# 4   Este é o início de uma série clássica de fant...                  NaN
# 5                         Gosto de obras filosóficas                    -
# 6         A abordagem da violência e controle social   amarela com flores
# 7   A crítica à sociedade de consumo e o uso da t...          nao importa
# 8                    Clássico da literatura francesa
# 9   A estrutura narrativa complexa e a análise ps...                  NaN

# %%
# juntar o nome e o sobrenome do autor em apenas uma coluna
# renomear as colunas da tabela de acordo com o banco de dados para facilitar o entendimento
# excluir a coluna capa_livro que nao sera armazenada no banco de dados

# %%
df_books.dtypes
# Out:
# titulo            object
# paginas          float64
# ano              float64
# genero            object
# localizacao       object
# lido              object
# classificacao     object
# autor             object
# pais              object
# nascimento       float64
# dtype: object

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   titulo         46 non-null     object
#  1   paginas        46 non-null     float64
#  2   ano            46 non-null     float64
#  3   genero         46 non-null     object
#  4   localizacao    46 non-null     object
#  5   lido           46 non-null     object
#  6   classificacao  44 non-null     object
#  7   autor          46 non-null     object
#  8   pais           46 non-null     object
#  9   nascimento     46 non-null     float64
# dtypes: float64(3), object(7)
# memory usage: 4.0+ KB

# %%
df_books.head(n = 3)
# Out:
#          titulo  paginas     ano             genero localizacao   lido  \
# 0  Dom Casmurro    280.0  1899.0            Romance           E  False
# 1           NaN      NaN     NaN                NaN         NaN    NaN
# 2          1984    328.0  1949.0  Ficção Científica           F   True
#
#   classificacao             autor         pais  nascimento
# 0             -  Machado de Assis           BR      1839.0
# 1           NaN               NaN          NaN         NaN
# 2             2     George Orwell  Reino Unido      1903.0

# %%
df_author = df_books[['autor', 'pais', 'nascimento']]
